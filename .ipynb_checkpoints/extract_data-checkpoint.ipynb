# %%
import pandas as pd

# %%
# Filepath for facility data file
facility_csv = "PA_facility_pollution.csv"

# Read the csv file
facility_data = pd.read_csv(facility_csv)

# Display the data table for preview
facility_data.head()
# Out:
#   Unique ID                                FacilityName  Rank_TRI_14  \
# 0  1.10E+11                                    3M ASTON      11432.0
# 1  1.10E+11  A P GREEN REFRACTORIES INC SPROUL PA PLANT       6709.0
# 2  1.10E+11                            ABERDEEN ROAD CO          NaN
# 3  1.10E+11                         LAKE REGION MEDICAL       1226.0
# 4  1.10E+11                               ACCURIDE ERIE      14007.0
#
#    Rank_GHG_14   Latitude  Longitude          LocationAddress  \
# 0          NaN  39.850112 -75.412138             50 MILTON DR
# 1          NaN  40.270910 -78.464737           2926 QUARRY RD
# 2          NaN  40.015787 -76.726143  105 E SINKING SPRING LN
# 3          NaN  40.195060 -75.486960            200 W 7TH AVE
# 4          NaN  42.131720 -80.058270           1015 E 12TH ST
#
#                City State        ZIP  ... Sixth_GHG_ID           TRI_ID  \
# 0  CHESTER TOWNSHIP    PA      19013  ...          NaN  19014CSTMC50MIL
# 1         CLAYSBURG    PA      16625  ...          NaN  16682GNRLRPOBOX
# 2        EMIGSVILLE    PA  173180435  ...          NaN  17310HRCLTABERD
# 3            TRAPPE    PA  194260992  ...          NaN  19426NFRMT200WE
# 4              ERIE    PA      16503  ...          NaN  16503KWLP 1015E
#
#    Second_TRI_ID  Third_TRI_ID  Fourth_TRI_ID Fifth_TRI_ID        FRS_ID  \
# 0            NaN           NaN            NaN          NaN  1.100000e+11
# 1            NaN           NaN            NaN          NaN  1.100000e+11
# 2            NaN           NaN            NaN          NaN  1.100000e+11
# 3            NaN           NaN            NaN          NaN  1.100000e+11
# 4            NaN           NaN            NaN          NaN  1.100000e+11
#
#   Second_FRS_ID Third_FRS_ID Fourth_FRS_ID
# 0           NaN          NaN           NaN
# 1           NaN          NaN           NaN
# 2           NaN          NaN           NaN
# 3           NaN          NaN           NaN
# 4           NaN          NaN           NaN
#
# [5 rows x 43 columns]

# %%
# Filepath for cancer data file
cancer_csv = "all_cancer_incidence.csv"

# Read the csv file
cancer_data = pd.read_csv(cancer_csv)

# Display the data table for preview
cancer_data.head()
# Out:
#            RateRatio  Cancer_Site     County  Year    Sex Race_Ethnicity  \
# 0  Age-Adjusted Rate  All Cancers      Adams  2014  Total      All Races
# 1  Age-Adjusted Rate  All Cancers      Adams  2014  Total      All Races
# 2  Age-Adjusted Rate  All Cancers      Adams  2014  Total      All Races
# 3  Age-Adjusted Rate  All Cancers      Adams  2014  Total      All Races
# 4  Age-Adjusted Rate  All Cancers  Allegheny  2014  Total      All Races
#
#         Age     Stage  Count Exp_Count        Pop RateRatioResult  \
# 0  All Ages  Invasive    606     645.8    101,714           434.2
# 1  All Ages     Early    343     373.7    101,714           252.2
# 2  All Ages      Late    273     291.6    101,714           195.7
# 3  All Ages   Unknown     48      47.3    101,714            32.4
# 4  All Ages  Invasive  7,859  7,575.80  1,231,255           487.9
#
#   LowerBound_Result UpperBoundResult SignificanceResult  County_Code
# 0             399.2            471.7                NaN            1
# 1             225.2            281.8                NaN            1
# 2             172.5            221.4                NaN            1
# 3              23.8             43.5                NaN            1
# 4             476.8            499.3                  +            3
